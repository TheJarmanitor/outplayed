# %%
import pandas as pd

df = pd.read_csv("../data/player_stats.csv").dropna(axis=1)
df.tail()
# Out:
#      Year  Rank             Player                 Club Nationality  Share  \
# 355    23    26      Jamal Musiala        Bayern Munich     Germany    0.0
# 356    23    27     Nicolò Barella          Inter Milan       Italy    0.0
# 357    23    28    Martin Ødegaard           Arsenal FC      Norway    0.0
# 358    23    28  Randal Kolo Muani  Eintracht Frankfurt      France    0.0
# 359    23    30         Rúben Dias      Manchester City    Portugal    0.0
#
#      Season  Goals  Assists  Yellow Cards  ...  Copa_do_Brasil_appearances  \
# 355    23.0     16       16             2  ...                         0.0
# 356    23.0      9       10            10  ...                         0.0
# 357    23.0     15        8             5  ...                         0.0
# 358    23.0     23       17             6  ...                         0.0
# 359    23.0      1        0             6  ...                         0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 66 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Year                                  360 non-null    int64
#  1   Rank                                  360 non-null    int64
#  2   Player                                360 non-null    object
#  3   Club                                  360 non-null    object
#  4   Nationality                           360 non-null    object
#  5   Share                                 360 non-null    float64
#  6   Season                                360 non-null    float64
#  7   Goals                                 360 non-null    int64
#  8   Assists                               360 non-null    int64
#  9   Yellow Cards                          360 non-null    int64
#  10  Red cards                             360 non-null    int64
# ...

# %%
df["Player"].value_counts()
# Out:
# Player
# Cristiano Ronaldo    15
# Lionel Messi         15
# Karim Benzema        10
# Kevin De Bruyne       9
# Neymar                9
#                      ..
# Dries Mertens         1
# Philippe Coutinho     1
# Raphaël Varane        1
# Roberto Firmino       1
# Randal Kolo Muani     1
# Name: count, Length: 131, dtype: int64
