# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/cleaned/player_stats.csv')

# %%
df.head(5)
# Out:
#    Year          Competition               Club  1 - 15  16 - 30  31 - 45  \
# 0    22       Premier League  Manchester United       2        0        6
# 1    22     Champions League  Manchester United       1        0        0
# 2    21              Serie A        Juventus FC       4        3        7
# 3    21            Italy Cup        Juventus FC       0        1        1
# 4    21  Supercoppa Italiana        Juventus FC       0        0        0
#
#    45+  46 - 60  61 - 75  76 - 90  90+  Extra time  Total             Player  \
# 0    1        2        5        2    0         0.0     18  Cristiano Ronaldo
# 1    1        0        0        2    2         0.0      6  Cristiano Ronaldo
# 2    1        3        2        8    1         0.0     29  Cristiano Ronaldo
# 3    0        0        0        0    0         0.0      2  Cristiano Ronaldo
# 4    0        0        1        0    0         0.0      1  Cristiano Ronaldo
#
#     Share
# 0  0.0000
# 1  0.0000
# 2  0.0654
# 3  0.0654
# ...
